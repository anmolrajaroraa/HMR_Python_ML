# %%
import bs4
import urllib.request as req

# %%
res = req.urlopen('https://www.flipkart.com/rr-m3-black-010-fitness-smart-band/p/itmfc5e8bzt4fmhg?pid=SBNFC368XHBUY2ZZ&lid=LSTSBNFC368XHBUY2ZZEBEVDI&marketplace=FLIPKART&srno=b_1_1&otracker=hp_omu_Deals%2Bof%2Bthe%2BDay_1_2.dealCard.OMU_KRIKER1KTHKH_2&otracker1=hp_omu_PINNED_neo%2Fmerchandising_Deals%2Bof%2Bthe%2BDay_NA_dealCard_cc_1_NA_view-all_2&fm=neo%2Fmerchandising&iid=ad757ae8-3bca-4c7f-8cc8-443dc8bb7120.SBNFC368XHBUY2ZZ.SEARCH&ppt=browse&ppn=browse&ssid=s9cac8rdb40000001561435822757')

# %%
res

# %%
page = bs4.BeautifulSoup(res)

# %%
len(page.find_all('a'))
# Out:
# 65

# %%
div = page.find('div', class_="_39LH-M")

# %%
anchor_list = div.find_all('a')

# %%
a = anchor_list[-1]

# %%
a
# Out:
# <a href="/rr-m3-black-010-fitness-smart-band/product-reviews/itmfc5e8bzt4fmhg?pid=SBNFC368XHBUY2ZZ"><div class="swINJg _3nrCtb"><span class="">All 586 reviews</span></div></a>

# %%
link = a['href']

# %%
link
# Out:
# '/rr-m3-black-010-fitness-smart-band/product-reviews/itmfc5e8bzt4fmhg?pid=SBNFC368XHBUY2ZZ'

# %%
completeLink = 'https://www.flipkart.com' + link

# %%
completeLink
# Out:
# 'https://www.flipkart.com/rr-m3-black-010-fitness-smart-band/product-reviews/itmfc5e8bzt4fmhg?pid=SBNFC368XHBUY2ZZ'

# %%
res2 = req.urlopen(completeLink)

# %%
page2 = bs4.BeautifulSoup(res2)

# %%
page2
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
# <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
# <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.46f631.css" rel="stylesheet"/>
# <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="102988293558" property="fb:page_id"/>
# <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
# <meta content="noodp" name="robots"/>
# <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon">
# <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
# <meta content="website" property="og:type"/>
# ...
